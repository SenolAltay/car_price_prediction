# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\SENOL\Desktop\Arac-Fiyat-Tahmini-main\Arac-Fiyat-Tahmini-main\Arac-Fiyat-Tahmini-Egea\1-Sahibinden-Veri-Cekme-Botu.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SENOL/Desktop/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-Egea/1-Sahibinden-Veri-Cekme-Botu.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from selenium import webdriver
#       <a href='vscode-notebook-cell:/c%3A/Users/SENOL/Desktop/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-Egea/1-Sahibinden-Veri-Cekme-Botu.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import time
#       <a href='vscode-notebook-cell:/c%3A/Users/SENOL/Desktop/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-Egea/1-Sahibinden-Veri-Cekme-Botu.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from selenium.webdriver.common.by import By
#
# ...

# %%
# Bu hazır fonksyonumuz adından da anlaşılacağı üzere listeyi string türüne çeviriyor.
def listToString(s):
    # initialize an empty string
    str1 = " "
    # return string
    return (str1.join(s))

# Bu aşamada selenium ile veri çekmeye başlıyoruz.
driver_path = "C:\Selenium\chromedriver.exe"
browser = webdriver.Chrome(driver_path)
#---------------------------------------------------------------------------------------------------------------
#---------------------------------------------------------------------------------------------------------------
#---------------------------------------------------------------------------------------------------------------
#---------------------------------------------------------------------------------------------------------------
j=0
while j<=40:
    
    browser.get("https://www.sahibinden.com/fiat?pagingOffset="+str(j)+"&a5_min=2015&a5_max=2020")
    i = 1
    while i <= 5:
        try:
            element = browser.find_element(By.XPATH, "//*[@id='searchResultsTable']/tbody/tr["+str(i)+"]")
            browser.execute_script("arguments[0].click();", element)
            # ÖZELLİKLERİ
            elements = browser.find_elements(By.CSS_SELECTOR, "div.classifiedInfo")

            # 2 tane boş liste oluşturuyoruz. Elimizdeki dağınık veriyi düzenleyip listeye atacağız.
            detaylar = []
            # özellikleri de stringe çevirerek listeye atıyoruz.
            for K in elements:
                detaylar.append(K.text)
            # elimizde string olan liste halinde veriler var. Önceden oluşturduğumuz listeden stringe çevirme fonksyonuyla stringe 
            # çeviriyoruz.
            det_str = listToString(detaylar)
            # string verimizi split ile satırlara göre ayırıyoruz. Ve ayrı adında değişkene atıyoruz.
            ayrı = det_str.split("\n")
            # demin oluşturduğumuz ayrı değişkenini DataFrame çeviriyoruz. 
            df = pd.DataFrame(ayrı)

            # Verimizdeki gereksiz verilerden kurtulmak için onları ayırıyoruz. 
            df_liste = df.values.tolist()
            # içerikler adında boş liste oluşturuyoruz, amacımız şu: şu an elimizdeki veri sütun adlarını ve içeriklerini barındırıyor.
            # içerikleri sütun adlarından ayırmak için bu işlemi yapıyoruz.
            içerikler = []
            K = 0
            while K < len(df_liste):
                içerikler.append(df_liste[K])
                K += 2
            # şuan liste halinde olan verimizi DataFrame'e çeviriyoruz ve transpozunu alıyoruz.
            df_içerikler = pd.DataFrame(içerikler).transpose()
            df_içerikler.to_csv(r"deneme.csv", encoding="utf-8", index=False, mode="a")
        except:
            time.sleep(5)
            element = browser.find_element(By.XPATH, "//*[@id='searchResultsTable']/tbody/tr["+str(i)+"]")
            browser.execute_script("arguments[0].click();", element)

        browser.execute_script("window.history.go(-1)")
        i = i+1
    j=j+20

    print(str(j)+"birinci kısım kısım")
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\SENOL\AppData\Local\Temp\ipykernel_14852\1429132859.py:9: SyntaxWarning: invalid escape sequence '\S'
#   driver_path = "C:\Selenium\chromedriver.exe"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\SENOL\Desktop\Arac-Fiyat-Tahmini-main\Arac-Fiyat-Tahmini-main\Arac-Fiyat-Tahmini-Egea\1-Sahibinden-Veri-Cekme-Botu.ipynb Cell 2 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/SENOL/Desktop/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-Egea/1-Sahibinden-Veri-Cekme-Botu.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> # Bu aşamada selenium ile veri çekmeye başlıyoruz.
# ...

# %%
df_zingat=pd.read_csv("egea.csv")

# %%
df_zingat
# Out:
#                0                                   1             2  \
# 0     434.750 TL     İstanbul / Ataşehir / İnönü Mh.  1.083647e+09
# 1              0                                   1  2.000000e+00
# 2     347.750 TL            İzmir / Buca / İnönü Mh.  1.085030e+09
# 3              0                                   1  2.000000e+00
# 4     530.000 TL   Gaziantep / Nurdağı / Aslanlı Mh.  1.085021e+09
# ...          ...                                 ...           ...
# 2130  495.000 TL    Ankara / Yenimahalle / Çarşı Mh.  1.085045e+09
# 2131           0                                   1  2.000000e+00
# 2132  495.000 TL    Ankara / Yenimahalle / Çarşı Mh.  1.085045e+09
# 2133           0                                   1  2.000000e+00
# 2134  429.500 TL  İstanbul / Bağcılar / 100. Yıl Mh.  1.084605e+09
#
#                    3        4        5                          6       7  \
# 0       13 Mart 2023    Fiat     Egea     1.3 Multijet Easy Plus   2019.0
# ...

# %%
i = 1
while i <= 2134:
    df_zingat.drop(i,inplace = True)
    i=i+2

# %%
df_zingat = df_zingat.reset_index()
df_zingat.drop("index", axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\SENOL\Desktop\Arac-Fiyat-Tahmini-main\Arac-Fiyat-Tahmini-main\Arac-Fiyat-Tahmini-Egea\1-Sahibinden-Veri-Cekme-Botu.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SENOL/Desktop/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-Egea/1-Sahibinden-Veri-Cekme-Botu.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> df_zingat = df_zingat.reset_index()
#       <a href='vscode-notebook-cell:/c%3A/Users/SENOL/Desktop/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-main/Arac-Fiyat-Tahmini-Egea/1-Sahibinden-Veri-Cekme-Botu.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> df_zingat.drop("index", axis = 1, inplace = True)
#
# NameError: name 'df_zingat' is not defined

# %%
df_zingat
# Out:
#                0                                   1             2  \
# 0     434.750 TL     İstanbul / Ataşehir / İnönü Mh.  1.083647e+09
# 1     347.750 TL            İzmir / Buca / İnönü Mh.  1.085030e+09
# 2     530.000 TL   Gaziantep / Nurdağı / Aslanlı Mh.  1.085021e+09
# 3            NaN                                 NaN           NaN
# 4     477.000 TL  Antalya / Muratpaşa / Ermenek Mah.  1.081546e+09
# ...          ...                                 ...           ...
# 1063  499.750 TL  İstanbul / Esenyurt / Gökevler Mh.  1.077954e+09
# 1064  499.750 TL  İstanbul / Esenyurt / Gökevler Mh.  1.077954e+09
# 1065  495.000 TL    Ankara / Yenimahalle / Çarşı Mh.  1.085045e+09
# 1066  495.000 TL    Ankara / Yenimahalle / Çarşı Mh.  1.085045e+09
# 1067  429.500 TL  İstanbul / Bağcılar / 100. Yıl Mh.  1.084605e+09
#
#                    3        4        5                          6       7  \
# 0       13 Mart 2023    Fiat     Egea     1.3 Multijet Easy Plus   2019.0
# ...

# %%
df_zingat.to_excel("egea.xlsx")
